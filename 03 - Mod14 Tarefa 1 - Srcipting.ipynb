# %% [markdown]
# # 1. Tarefa 1 - modulo 14

# %% [markdown]
# **1.A - Crie um jupyter notebook com os imports necessários e um código para gerar os
# gráficos referentes a base de dados de março, abril, maio, junho e dezembro
# (numa célula só ou em várias).**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os


sns.set_theme()  


sinasc = pd.read_csv('./input/SINASC_RO_2019_MAR.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao = 'nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).unstack().plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None
    
    
max_data = sinasc.DTNASC.max()[:7]

os.makedirs('./output/figs/'+max_data, exist_ok = True)

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'mean', 'média idade mãe', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/media idade mae.png')

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quabtidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade bebês ao longo do tempo')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'count',
                  'idade Mãe', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'count',
                  'média peso bebê', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media peso do bebê por sexo')

plota_pivot_table(sinasc, 'PESO', ['ESCMAE'], 'mean',
                  'peso bebê', 'escolalidade da Mãe', 'sort')
plt.savefig('./output/figs/'+max_data+'/peso x escolaridade mãe')

plota_pivot_table(sinasc, 'APGAR1', ['GESTACAO'], 'mean',
                  'apgar 1 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar1')

plota_pivot_table(sinasc, 'APGAR5', ['GESTACAO'], 'mean',
                  'apgar 5 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar5')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os


sns.set_theme()  


sinasc = pd.read_csv('./input/SINASC_RO_2019_ABR.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao = 'nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).unstack().plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None
    
    
max_data = sinasc.DTNASC.max()[:7]

os.makedirs('./output/figs/'+max_data, exist_ok = True)

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'mean', 'média idade mãe', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/media idade mae.png')

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quabtidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade bebês ao longo do tempo')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'count',
                  'idade Mãe', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'count',
                  'média peso bebê', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media peso do bebê por sexo')

plota_pivot_table(sinasc, 'PESO', ['ESCMAE'], 'mean',
                  'peso bebê', 'escolalidade da Mãe', 'sort')
plt.savefig('./output/figs/'+max_data+'/peso x escolaridade mãe')

plota_pivot_table(sinasc, 'APGAR1', ['GESTACAO'], 'mean',
                  'apgar 1 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar1')

plota_pivot_table(sinasc, 'APGAR5', ['GESTACAO'], 'mean',
                  'apgar 5 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar5')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os


sns.set_theme()  


sinasc = pd.read_csv('./input/SINASC_RO_2019_MAI.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao = 'nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).unstack().plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None
    
    
max_data = sinasc.DTNASC.max()[:7]

os.makedirs('./output/figs/'+max_data, exist_ok = True)

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'mean', 'média idade mãe', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/media idade mae.png')

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quabtidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade bebês ao longo do tempo')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'count',
                  'idade Mãe', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'count',
                  'média peso bebê', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media peso do bebê por sexo')

plota_pivot_table(sinasc, 'PESO', ['ESCMAE'], 'mean',
                  'peso bebê', 'escolalidade da Mãe', 'sort')
plt.savefig('./output/figs/'+max_data+'/peso x escolaridade mãe')

plota_pivot_table(sinasc, 'APGAR1', ['GESTACAO'], 'mean',
                  'apgar 1 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar1')

plota_pivot_table(sinasc, 'APGAR5', ['GESTACAO'], 'mean',
                  'apgar 5 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar5')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os


sns.set_theme()  


sinasc = pd.read_csv('./input/SINASC_RO_2019_JUN.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao = 'nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).unstack().plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None
    
    
max_data = sinasc.DTNASC.max()[:7]

os.makedirs('./output/figs/'+max_data, exist_ok = True)

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'mean', 'média idade mãe', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/media idade mae.png')

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quabtidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade bebês ao longo do tempo')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'count',
                  'idade Mãe', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'count',
                  'média peso bebê', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media peso do bebê por sexo')

plota_pivot_table(sinasc, 'PESO', ['ESCMAE'], 'mean',
                  'peso bebê', 'escolalidade da Mãe', 'sort')
plt.savefig('./output/figs/'+max_data+'/peso x escolaridade mãe')

plota_pivot_table(sinasc, 'APGAR1', ['GESTACAO'], 'mean',
                  'apgar 1 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar1')

plota_pivot_table(sinasc, 'APGAR5', ['GESTACAO'], 'mean',
                  'apgar 5 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar5')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os


sns.set_theme()  


sinasc = pd.read_csv('./input/SINASC_RO_2019_DEZ.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao = 'nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).unstack().plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None
    
    
max_data = sinasc.DTNASC.max()[:7]

os.makedirs('./output/figs/'+max_data, exist_ok = True)

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'mean', 'média idade mãe', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/media idade mae.png')

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quabtidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade bebês ao longo do tempo')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'count',
                  'idade Mãe', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'count',
                  'média peso bebê', 'data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/media peso do bebê por sexo')

plota_pivot_table(sinasc, 'PESO', ['ESCMAE'], 'mean',
                  'peso bebê', 'escolalidade da Mãe', 'sort')
plt.savefig('./output/figs/'+max_data+'/peso x escolaridade mãe')

plota_pivot_table(sinasc, 'APGAR1', ['GESTACAO'], 'mean',
                  'apgar 1 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar1')

plota_pivot_table(sinasc, 'APGAR5', ['GESTACAO'], 'mean',
                  'apgar 5 médio', 'gestação', 'sort')
plt.savefig('./output/figs/'+max_data+'/gestação x apgar5')

# %% [markdown]
# **1.B - Como que você poderia fazer para deixar isso mais automatizado? Descreva na
# última célula do jupyter notebook o que ajudaria na hora de gerar novos gráficos
# pros meses/anos seguintes.**

# %% [markdown]
# Para deixar este scripting mais automatizado, poderia primeiro transformar este arquivo do scripting em ".py". Alterar o código para extrair os dados direto do site, utilizando o 'url' do website, bem como utilizando o comando requests.get(url), posteriormente r.jason(), baixando os itens do arquivo. Posteriormente, agendar através no agendador de tarefas do windows. Se o sistema operacional for Linux, pode agendar a tarefa através do aplicativo Crontab.
